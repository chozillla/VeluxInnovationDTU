# %% [markdown]
# ## This is a notebook analyzing data for a survery
#
#
# [Here is the survey!](https://forms.office.com/Pages/DesignPageV2.aspx?subpage=design&token=45b140a95f2a4b0faab6492704fc3d8a&id=I_FR8s7JjkSSdzS7KFkR2QF4gBPhZqdLp7u4C_R3poFUODJOMzk2UUE0UTI3U0pRUDdVUVNSTVozUiQlQCN0PWcu&tab=0&analysis=true)

# %%
# Importing packages 

import pandas as pd
import seaborn as sns
from wordcloud import WordCloud
from collections import Counter
import matplotlib.pyplot as plt
import os

# %%
# Get the current directory
current_directory = os.getcwd()
print("Current Directory:", current_directory)

# List all objects (files and subdirectories) in the current directory
objects_in_directory = os.listdir(current_directory)

# Iterate through the objects and print their paths
for obj in objects_in_directory:
    obj_path = os.path.join(current_directory, obj)
    print(obj_path)
# Out:
# Current Directory: /Users/chemay/Documents/GitHub/VeluxInnovationDTU
# /Users/chemay/Documents/GitHub/VeluxInnovationDTU/Survey_230803.csv
# /Users/chemay/Documents/GitHub/VeluxInnovationDTU/Survery.ipynb
# /Users/chemay/Documents/GitHub/VeluxInnovationDTU/.ipynb_checkpoints
# /Users/chemay/Documents/GitHub/VeluxInnovationDTU/.git
# /Users/chemay/Documents/GitHub/VeluxInnovationDTU/heatmap.png

# %%
df = pd.read_csv('/Users/chemay/Documents/GitHub/VeluxInnovationDTU/Survey_230803.csv')

# %%
df.sample(5)
# Out:
#       ID       Start time  Completion time  Last modified time  \
# 24  25.0  8/8/23 13:25:18  8/8/23 13:27:06                 NaN
# 41  42.0  8/8/23 19:26:45  8/8/23 19:27:37                 NaN
# 6    7.0  8/8/23 11:06:59  8/8/23 11:17:57                 NaN
# 37  38.0  8/8/23 17:31:33  8/8/23 17:32:26                 NaN
# 63   NaN              NaN              NaN                 NaN
#
#    How much time do you spend indoors on average per day? (excluding sleep)  \
# 24                                                NaN
# 41                                  Less than 6 hours
# 6                                         12-18 hours
# 37                                         6-12 hours
# 63                                                NaN
#
#    How much natural daylight do you get in your home?  \
# 24                                                NaN
# 41                                                NaN
# 6                                                 NaN
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Start time', 'Completion time', 'Last modified time',
#        'How much time do you spend indoors on average per day? (excluding sleep)',
#        'How much natural daylight do you get in your home?',
#        'How satisfied are you with the indoor climate of your home?',
#        'Which aspects of indoor climate bothers you the most? (Please select 2 options)',
#        'How satisfied are you with the indoor ventilation quality?',
#        'How content are you with the level of indoor noise reduction at your home?',
#        'How satisfied are you with your indoor heating & cooling system at your home?',
#        'How often do you open your windows to let in fresh air?',
#        'How many hours a day do you use artificial light indoors?',
#        'How do you place your trust in intelligent home control systems? (fx Amazon Alexa, automatic smart-windows etc.)\n',
#        'Which products are you most interested in installing or renewing in your home?',
# ...

# %%
# Assuming 'df' is your DataFrame
plt.figure(figsize=(10, 6))

# Create the bar plot
gender_counts = df["What's your gender?"].value_counts()
gender_counts.plot(kind='bar')

# Add frequency counts on the bars
for i, count in enumerate(gender_counts):
    plt.text(i, count + 2, str(count), ha='center', va='bottom', fontsize=10)

# Add title with the total number of respondents
total_respondents = len(df)
plt.title(f'Distribution of Gender (Total Respondents n = {total_respondents})')

plt.xlabel('Categories')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/r6/dxzpcwbs7nl9hmnylb1644gh0000gn/T/ipykernel_51293/163257634.py in <module>
#       1 # Assuming 'df' is your DataFrame
# ----> 2 plt.figure(figsize=(10, 6))
#       3
#       4 # Create the bar plot
#       5 gender_counts = df["What's your gender?"].value_counts()
#
# NameError: name 'plt' is not defined

# %%
# Assuming 'df' is your DataFrame
plt.figure(figsize=(10, 6))

# Create the bar plot
gender_counts = df['How old are you?2'].value_counts()
gender_counts.plot(kind='bar')

# Add frequency counts on the bars
for i, count in enumerate(gender_counts):
    plt.text(i, count + 2, str(count), ha='center', va='bottom', fontsize=10)

# Add title with the total number of respondents
total_respondents = len(df)
plt.title(f'Distribution of Gender (Total Respondents n = {total_respondents})')

plt.xlabel('Categories')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Assuming 'df' is your DataFrame
plt.figure(figsize=(10, 6))

# Create the bar plot
gender_counts = df["What's your living situation?"].value_counts()
gender_counts.plot(kind='bar')

# Add frequency counts on the bars
for i, count in enumerate(gender_counts):
    plt.text(i, count + 2, str(count), ha='center', va='bottom', fontsize=10)

# Add title with the total number of respondents
total_respondents = len(df)
plt.title(f'Distribution of Gender (Total Respondents n = {total_respondents})')

plt.xlabel('Categories')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Assuming 'df' is your DataFrame
plt.figure(figsize=(10, 6))

# Create the bar plot
gender_counts = df[ 'Where do you live?'].value_counts()
gender_counts.plot(kind='bar')

# Add frequency counts on the bars
for i, count in enumerate(gender_counts):
    plt.text(i, count + 2, str(count), ha='center', va='bottom', fontsize=10)

# Add title with the total number of respondents
total_respondents = len(df)
plt.title(f'Distribution of Gender (Total Respondents n = {total_respondents})')

plt.xlabel('Categories')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Can you elaborate on how those aspects effects you?

# %%
# Combine all text data into a single string
text_data = ' '.join(df['Can you elaborate on how those aspects effects you?'].dropna())

# Generate a word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text_data)

plt.figure(figsize=(10, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
df['Can you elaborate on how those aspects effects you?']

# %% [markdown]
# ## 'Do you have any additional thoughts or comments regarding this survey?'

# %%
# Combine all text data into a single string
text_data = ' '.join(df['Do you have any additional thoughts or comments regarding this survey?'].dropna())

# Generate a word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text_data)

plt.figure(figsize=(10, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
# Combine all text data into a single string
text_data = ' '.join(df["Do you have an idea of what could improve your indoor climate at home?"].dropna())

# Generate a word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text_data)

plt.figure(figsize=(10, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
# Get the column names from your DataFrame
columns_to_analyze = [
    "How satisfied are you with the indoor climate of your home?",
    "Which aspects of indoor climate bothers you the most? (Please select 2 options)",
    "How satisfied are you with the indoor ventilation quality?",
    "Do you have an idea of what could improve your indoor climate at home?"
    # ... add more columns you want to analyze
]

for column in columns_to_analyze:
    words = ' '.join(str(x) for x in df[column].fillna('')).split()
    word_counts = Counter(words)
    common_words = word_counts.most_common(15)

    plt.figure(figsize=(10, 6))
    plt.bar(*zip(*common_words))
    plt.title(f'Most Common Words in "{column}"')
    plt.xlabel('Words')
    plt.ylabel('Frequency')
    plt.xticks(rotation=45)
    plt.show()

# %%
columns_to_analyze = ["How much time do you spend indoors on average per day? (excluding sleep)",
       "How much natural daylight do you get in your home?",
       "How satisfied are you with the indoor climate of your home?",
       "Which aspects of indoor climate bothers you the most? (Please select 2 options)",
       "How satisfied are you with the indoor ventilation quality?",
       "How content are you with the level of indoor noise reduction at your home?",
       "How satisfied are you with your indoor heating & cooling system at your home?",
       "How often do you open your windows to let in fresh air?",
       "How many hours a day do you use artificial light indoors?",
       "How do you place your trust in intelligent home control systems? (fx Amazon Alexa, automatic smart-windows etc.)\n",
       "Which products are you most interested in installing or renewing in your home?",
       "What's your gender?", "How old are you?2",
       "Can you elaborate on how those aspects effects you?",
       "What's your living situation?", "Where do you live?",
       "Do you have an idea of what could improve your indoor climate at home?",
       "Do you have any additional thoughts or comments regarding this survey?"
                     ]  # Add columns you want to analyze
common_word_counts = {}

# Find the union of all unique words across columns
all_words = set()
for column in columns_to_analyze:
    words = ' '.join(str(x) for x in df[column].fillna('')).split()
    all_words.update(words)

# Normalize word frequencies to a consistent length
for column in columns_to_analyze:
    words = ' '.join(str(x) for x in df[column].fillna('')).split()
    word_counts = Counter(words)
    normalized_word_counts = [word_counts[word] if word in word_counts else 0 for word in all_words]
    common_word_counts[column] = normalized_word_counts

df_common_words = pd.DataFrame(common_word_counts)

# Calculate the correlation matrix
correlation_matrix = df_common_words.corr()

plt.figure(figsize=(20, 16))  # Increase the width of the figure
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', center=0, linewidths=0.5, fmt=".2f")
plt.title('Correlation Heatmap for Common Words', fontsize=16)
plt.xticks(rotation=45, fontsize=10, ha='right')
plt.yticks(rotation=0, fontsize=12)
plt.tight_layout()

# Save the figure as a PNG image
plt.savefig('heatmap.png', dpi=300)  # You can adjust the dpi (dots per inch) value if needed

plt.show()

# %%
df.columns

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import nltk
import ssl
try:
    _create_unverified_https_context = ssl._create_unverified_context
except AttributeError:
    pass
else:
    ssl._create_default_https_context = _create_unverified_https_context
nltk.download()
from gensim import corpora, models
from textblob import TextBlob
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml

# %%
# List of columns with text responses
text_columns = columns_to_analyze

# Tokenization and preprocessing
nltk.download('punkt')
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))

def preprocess_text(text):
    words = word_tokenize(text.lower())
    filtered_words = [word for word in words if word.isalnum() and word not in stop_words]
    return filtered_words

# Perform topic modeling and sentiment analysis for each column
for text_column in text_columns:
    df['preprocessed_text'] = df[text_column].apply(preprocess_text)
    
    # Create a dictionary and corpus for LDA
    dictionary = corpora.Dictionary(df['preprocessed_text'])
    corpus = [dictionary.doc2bow(text) for text in df['preprocessed_text']]
    
    # Perform LDA topic modeling
    lda_model = models.LdaModel(corpus, num_topics=5, id2word=dictionary, passes=15)
    
    # Print the topics for this column
    print(f"Topics for {text_column}:")
    for idx, topic in lda_model.print_topics(-1):
        print(f"Topic {idx}: {topic}")
    
    # Sentiment analysis using TextBlob
    def get_sentiment(text):
        blob = TextBlob(text)
        sentiment = blob.sentiment
        return sentiment.polarity, sentiment.subjectivity
    
    df['polarity'], df['subjectivity'] = zip(*df[text_column].apply(get_sentiment))
    
    # Print sentiment analysis results for this column
    print(f"Sentiment analysis for {text_column}:")
    print(df[['polarity', 'subjectivity']])
    
    # Optionally, you can save the preprocessed DataFrame to a CSV file
    # df.to_csv(f'processed_data_{text_column}.csv', index=False)
    print("=" * 50)
